# %% [markdown]
# # Generador de archivo de PDF para presupuesto

# %%
# Instalar libreria fpdg para trabajar con pdf
# ! pip install fpdf

# %%
from fpdf import FPDF

# %%
proyecto = " Proyecto de Python"
horas_estimadas = 20
costo_hora = 30
tiempo_estimado = 2 
valor_total = horas_estimadas * costo_hora

# %%
pdf = FPDF()

pdf.add_page()
pdf.set_font("Arial", size=12)

pdf.image("Template.png", 0, 0)

pdf.text(115, 145, str(proyecto))
pdf.text(115, 160, str(horas_estimadas))
pdf.text(115, 175, str(costo_hora))
pdf.text(115, 190, str(tiempo_estimado))
pdf.text(115, 205, f"{valor_total:.2f}")

pdf.output("presupuesto_ejemeplo.pdf")
print("El presupuesto ha sido generado exitosamente.")
# Out:
# El presupuesto ha sido generado exitosamente.

# %% [markdown]
# ![image.png](attachment:image.png)
